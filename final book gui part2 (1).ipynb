# %%
from tkinter import *
from PIL import ImageTk, Image
import customtkinter
from experta import *
class find_books(KnowledgeEngine):
	@DefFacts()
	def _initial_action(self):
		gui_form1 = Tk()
		#gui_form.configure(bg="#FFFFFF")
		gui_form1.title("Library Expert System")
###############################################################################
		photo=PhotoImage(file="book-clip-art-4.png")
		res=photo.subsample(12,12)
		btn=Label(gui_form1 , image=res , width=500 )
		btn.pack(pady=7)
###############################################################################
###############################################################################
		mylb1 = Label(gui_form1,text="‣ Mathematics Section" ,fg="#000000" , font=("Helvetica", 12 , "bold" ))
		mylb1.pack()
		lb1 = Label(gui_form1,text=" Algebra " ,fg="#643719" )
		en1 = Entry(gui_form1  , width=40)
		lb1.pack()
		en1.pack()
###############################################################################
		lb2 = Label(gui_form1,text="Calculus",fg="#643719" )
		en2 = Entry(gui_form1 , width=40)
		lb2.pack()
		en2.pack()
###############################################################################
		mylb3 = Label(gui_form1,text="‣ Geology Section" ,fg="#000000" , font=("Helvetica", 12 , "bold" ))
		mylb3.pack()
		lb3 = Label(gui_form1,text="Structural geology",fg="#643719")
		en3 = Entry(gui_form1, width=40)
		lb3.pack()
		en3.pack()
###############################################################################
		lb4 = Label(gui_form1,text="Volcanology",fg="#643719")
		en4 = Entry(gui_form1, width=40)
		lb4.pack()
		en4.pack()
###############################################################################
		mylb5 = Label(gui_form1,text="‣ Geography Section" ,fg="#000000" , font=("Helvetica", 12 , "bold"))
		mylb5.pack()
		lb5 = Label(gui_form1,text="Human Geography ",fg="#643719")
		en5 = Entry(gui_form1, width=40)
		lb5.pack()
		en5.pack()
###############################################################################
		lb6 = Label(gui_form1,text="Geographic IS" ,fg="#643719")
		en6 = Entry(gui_form1, width=40)
		lb6.pack()
		en6.pack()
###############################################################################
		mylb7 = Label(gui_form1,text="‣ Psychology Section" ,fg="#000000" , font=("Helvetica", 12 , "bold") )
		mylb7.pack()
		lb7= Label(gui_form1,text="Social Psychology" ,fg="#643719")
		en7= Entry(gui_form1, width=40)
		lb7.pack()
		en7.pack()
###############################################################################
		lb8 = Label(gui_form1,text="Health Psychology" ,fg="#643719")
		en8 = Entry(gui_form1, width=40)
		lb8.pack()
		en8.pack()
###############################################################################
		mylb9 = Label(gui_form1,text="‣ Art Section" ,fg="#000000" , font=("Helvetica", 12 , "bold") )
		mylb9.pack()
		lb9 = Label(gui_form1,text="Poetry" ,fg="#643719")
		en9 = Entry(gui_form1, width=40)
		lb9.pack()
		en9.pack()
###############################################################################
		lb10 = Label(gui_form1,text="Drama" ,fg="#643719")
		en10 = Entry(gui_form1, width=40)
		lb10.pack()
		en10.pack()
###############################################################################
		mylb11 = Label(gui_form1,text="‣ Media Section" ,fg="#000000" , font=("Helvetica", 12 , "bold") )
		mylb11.pack()
		lb11 = Label(gui_form1,text="Printing media" ,fg="#643719")
		en11 = Entry(gui_form1, width=40)
		lb11.pack()
		en11.pack()
###############################################################################
		lb12 = Label(gui_form1,text="Broadcast media" ,fg="#643719")
		en12= Entry(gui_form1, width=40)
		lb12.pack()
		en12.pack()
##############################################################################
		def get_values():
			#lb2["text"] = en2.get()
			self.declare(Fact(Algebra=en1.get()))
			self.declare(Fact(Calculus=en2.get()))
			self.declare(Fact(Structural_geology=en3.get()))
			self.declare(Fact(Volcanology=en4.get()))
			self.declare(Fact(Human_geo=en5.get()))
			self.declare(Fact(GIS=en6.get()))
			self.declare(Fact(Social_Psychology=en7.get()))
			self.declare(Fact(Health_Psychology=en8.get()))
			self.declare(Fact(Poetry=en9.get()))
			self.declare(Fact(Drama=en10.get()))
			self.declare(Fact(Printing=en11.get()))
			self.declare(Fact(Broadcast=en12.get()))
#############################################################################
		btn = Button(gui_form1,command=get_values,text="SHOW BOOK",bg="#5B4C42", fg="#FFFFFF" , pady=2 , width=13 )
		btn.config(font=("Arial", 10))
		btn.pack(pady=5)
                 
		gui_form1.mainloop()
		yield Fact(action="find_books")
        

###################################################################################################
##################################################################################################

	@Rule(Fact(action='find_books'),Fact(Algebra="yes"),Fact(Calculus="no") ,Fact(Structural_geology="no"),Fact(Volcanology="no"),Fact(Human_geo="no"),Fact(GIS="no"),Fact(Social_Psychology="no"),Fact(Health_Psychology="no"),Fact(Poetry="no"),Fact(Drama="no"),Fact(Printing="no"),Fact(Broadcast="no"))
	def value_0(self):
		self.declare(Fact(novel="Abstract Algebra"))

	@Rule(Fact(action='find_books'),Fact(Algebra="no"),Fact(Calculus="yes") ,Fact(Structural_geology="no"),Fact(Volcanology="no"),Fact(Human_geo="no"),Fact(GIS="no"),Fact(Social_Psychology="no"),Fact(Health_Psychology="no"),Fact(Poetry="no"),Fact(Drama="no"),Fact(Printing="no"),Fact(Broadcast="no"))
	def value_1(self):
		self.declare(Fact(novel="intermediate Calculus"))
        
	@Rule(Fact(action='find_books'),Fact(Algebra="no"),Fact(Calculus="no") ,Fact(Structural_geology="yes"),Fact(Volcanology="no"),Fact(Human_geo="no"),Fact(GIS="no"),Fact(Social_Psychology="no"),Fact(Health_Psychology="no"),Fact(Poetry="no"),Fact(Drama="no"),Fact(Printing="no"),Fact(Broadcast="no"))
	def value_2(self):
		self.declare(Fact(novel="The Mapping of Geological Structures"))
        
	@Rule(Fact(action='find_books'),Fact(Algebra="no"),Fact(Calculus="no") ,Fact(Structural_geology="no"),Fact(Volcanology="yes"),Fact(Human_geo="no"),Fact(GIS="no"),Fact(Social_Psychology="no"),Fact(Health_Psychology="no"),Fact(Poetry="no"),Fact(Drama="no"),Fact(Printing="no"),Fact(Broadcast="no"))
	def value_3(self):
		self.declare(Fact(novel="Introducing Volcanology"))
        
	@Rule(Fact(action='find_books'),Fact(Algebra="no"),Fact(Calculus="no") ,Fact(Structural_geology="no"),Fact(Volcanology="no"),Fact(Human_geo="yes"),Fact(GIS="no"),Fact(Social_Psychology="no"),Fact(Health_Psychology="no"),Fact(Poetry="no"),Fact(Drama="no"),Fact(Printing="no"),Fact(Broadcast="no"))
	def value_4(self):
		self.declare(Fact(novel="Population Geography"))
        
	@Rule(Fact(action='find_books'),Fact(Algebra="no"),Fact(Calculus="no") ,Fact(Structural_geology="no"),Fact(Volcanology="no"),Fact(Human_geo="no"),Fact(GIS="yes"),Fact(Social_Psychology="no"),Fact(Health_Psychology="no"),Fact(Poetry="no"),Fact(Drama="no"),Fact(Printing="no"),Fact(Broadcast="no"))
	def value_5(self):
		self.declare(Fact(novel="Getting to Know Web GIS"))
        
	@Rule(Fact(action='find_books'),Fact(Algebra="no"),Fact(Calculus="no") ,Fact(Structural_geology="no"),Fact(Volcanology="no"),Fact(Human_geo="no"),Fact(GIS="no"),Fact(Social_Psychology="yes"),Fact(Health_Psychology="no"),Fact(Poetry="no"),Fact(Drama="no"),Fact(Printing="no"),Fact(Broadcast="no"))
	def value_6(self):
		self.declare(Fact(novel="Outliers The Story of Success"))

	@Rule(Fact(action='find_books'),Fact(Algebra="no"),Fact(Calculus="no") ,Fact(Structural_geology="no"),Fact(Volcanology="no"),Fact(Human_geo="no"),Fact(GIS="no"),Fact(Social_Psychology="no"),Fact(Health_Psychology="yes"),Fact(Poetry="no"),Fact(Drama="no"),Fact(Printing="no"),Fact(Broadcast="no"))
	def value_7(self):
		self.declare(Fact(novel="Why We Sleep"))
        
	@Rule(Fact(action='find_books'),Fact(Algebra="no"),Fact(Calculus="no") ,Fact(Structural_geology="no"),Fact(Volcanology="no"),Fact(Human_geo="no"),Fact(GIS="no"),Fact(Social_Psychology="no"),Fact(Health_Psychology="no"),Fact(Poetry="yes"),Fact(Drama="no"),Fact(Printing="no"),Fact(Broadcast="no"))
	def value_8(self):
		self.declare(Fact(novel="Milk and honey"))
        
	@Rule(Fact(action='find_books'),Fact(Algebra="no"),Fact(Calculus="no") ,Fact(Structural_geology="no"),Fact(Volcanology="no"),Fact(Human_geo="no"),Fact(GIS="no"),Fact(Social_Psychology="no"),Fact(Health_Psychology="no"),Fact(Poetry="no"),Fact(Drama="yes"),Fact(Printing="no"),Fact(Broadcast="no"))
	def value_9(self):
		self.declare(Fact(novel="Towords Zero"))
        
	@Rule(Fact(action='find_books'),Fact(Algebra="no"),Fact(Calculus="no") ,Fact(Structural_geology="no"),Fact(Volcanology="no"),Fact(Human_geo="no"),Fact(GIS="no"),Fact(Social_Psychology="no"),Fact(Health_Psychology="no"),Fact(Poetry="no"),Fact(Drama="no"),Fact(Printing="yes"),Fact(Broadcast="no"))
	def value_10(self):
		self.declare(Fact(novel="Reporting for the print media"))
        
	@Rule(Fact(action='find_books'),Fact(Algebra="no"),Fact(Calculus="no") ,Fact(Structural_geology="no"),Fact(Volcanology="no"),Fact(Human_geo="no"),Fact(GIS="no"),Fact(Social_Psychology="no"),Fact(Health_Psychology="no"),Fact(Poetry="no"),Fact(Drama="no"),Fact(Printing="no"),Fact(Broadcast="yes"))
	def value_11(self):
		self.declare(Fact(novel="The Routledge Companion To History And The Moving Image"))
        
	@Rule(Fact(action='find_books'),Fact(Algebra="no"),Fact(Calculus="no") ,Fact(Structural_geology="no"),Fact(Volcanology="no"),Fact(Human_geo="no"),Fact(GIS="no"),Fact(Social_Psychology="no"),Fact(Health_Psychology="no"),Fact(Poetry="no"),Fact(Drama="no"),Fact(Printing="no"),Fact(Broadcast="no"))
	def value_12(self):
		self.declare(Fact(novel="ERORR"))

###################################################################################################
##################################################################################################
	@Rule(Fact(action='find_books'),Fact(novel=MATCH.novel))
	def my_novel(self, novel):
		print("")
		my_novel = novel
		gui_form2 = Tk()
		gui_form2.configure(bg="#FFFFFF")
		gui_form2.title("Library expert system answer")
		gui_form2.geometry("800x500")
		lb0 = Label(gui_form2,text="We Recommend This Book to You :", bg="#FFFFFF", fg="#000000")
		lb0.pack(pady=25)
		lb0.config(font=("Helvetica", 20 , "bold"  ) , width=100 )
		var = StringVar()
		var.set(my_novel)
		lb1 = Label(gui_form2, textvariable = var,bg="#FFFFFF", fg="#000000")
		lb1.config(font=("Helvetica", 20 , "bold"  , "italic") , width=120 )
		lb1.pack(pady=10)
		frame = Frame(gui_form2, width=200, height=200)
		frame.pack(pady=60)
		img = ImageTk.PhotoImage(Image.open("cover34.png"))
		label = Label(frame, image = img)
		label.pack()
		gui_form2.mainloop()

###################################################################################################
##################################################################################################
        
engine = find_books()
while(1):
    engine.reset()
    engine.run()  
    print("Would you like to get another recommendation of Books?")
    if input() == "no":
        break;
# Out:
# WARNING:experta.watchers.ENGINE:Declaring fact before reset()
