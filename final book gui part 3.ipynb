# %%
from tkinter import *
from PIL import ImageTk, Image
import customtkinter
from experta import *
class find_books(KnowledgeEngine):
	@DefFacts()
	def _initial_action(self):
		gui_form1 = Tk()
		#gui_form.configure(bg="#FFFFFF")
		gui_form1.title("Library Expert System")
###############################################################################
		photo=PhotoImage(file="book-clip-art-4.png")
		res=photo.subsample(12,12)
		btn=Label(gui_form1 , image=res , width=500 )
		btn.pack(pady=15)
###############################################################################
###############################################################################
		mylb1 = Label(gui_form1,text="‣ Medical-Science Section" ,fg="#000000" , font=("Helvetica", 12 , "bold" ))
		mylb1.pack()
		lb1 = Label(gui_form1,text=" Pediatrics" ,fg="#643719" )
		en1 = Entry(gui_form1  , width=40)
		lb1.pack()
		en1.pack()
###############################################################################
		lb2 = Label(gui_form1,text="Interal Medicine",fg="#643719" )
		en2 = Entry(gui_form1 , width=40)
		lb2.pack()
		en2.pack()
###############################################################################
		mylb3 = Label(gui_form1,text="‣ Economics-Science Section" ,fg="#000000" , font=("Helvetica", 12 , "bold" ))
		mylb3.pack()
		lb3 = Label(gui_form1,text="Microeconomics",fg="#643719")
		en3 = Entry(gui_form1, width=40)
		lb3.pack()
		en3.pack()
###############################################################################
		lb4 = Label(gui_form1,text="Macroeconomics",fg="#643719")
		en4 = Entry(gui_form1, width=40)
		lb4.pack()
		en4.pack()
###############################################################################
		mylb5 = Label(gui_form1,text="‣ Computer-Science Section" ,fg="#000000" , font=("Helvetica", 12 , "bold"))
		mylb5.pack(pady=10)
		lb5 = Label(gui_form1,text="Programming Language " ,fg="#643719" )
		en5 = Entry(gui_form1, width=40)
		lb5.pack()
		en5.pack()
###############################################################################
		mylb6 = Label(gui_form1,text="‣ Database Section" ,fg="#000000" , font=("Helvetica", 10 , "bold"))
		mylb6.pack()
		lb6 = Label(gui_form1,text=" SQL database " ,fg="#643719")
		en6 = Entry(gui_form1, width=25)
		lb6.pack()
		en6.pack()
###############################################################################
		lb7= Label(gui_form1,text=" No SQL Database" ,fg="#643719")
		en7= Entry(gui_form1, width=25)
		lb7.pack()
		en7.pack()
###############################################################################
		mylb8 = Label(gui_form1,text="‣ Engineering Section" ,fg="#000000" , font=("Helvetica", 12 , "bold") )
		mylb8.pack(pady=7)
		lb8 = Label(gui_form1,text="Architecture" ,fg="#643719")
		en8 = Entry(gui_form1, width=40)
		lb8.pack()
		en8.pack()
###############################################################################
		lb9 = Label(gui_form1,text="Civil Engineering " ,fg="#643719")
		en9 = Entry(gui_form1, width=40)
		lb9.pack()
		en9.pack()
###############################################################################
		mylb10 = Label(gui_form1,text="‣ Law Section" ,fg="#000000" , font=("Helvetica", 12 , "bold") )
		mylb10.pack()
		lb10 = Label(gui_form1,text="Family Law" ,fg="#643719")
		en10 = Entry(gui_form1, width=40)
		lb10.pack()
		en10.pack()
###############################################################################
		lb11 = Label(gui_form1,text="Criminal Law" ,fg="#643719")
		en11 = Entry(gui_form1, width=40)
		lb11.pack()
		en11.pack()
###############################################################################
##############################################################################
		def get_values():
			#lb2["text"] = en2.get()
			self.declare(Fact(pediatrics=en1.get()))
			self.declare(Fact(Medicine=en2.get()))
			self.declare(Fact(Micro=en3.get()))
			self.declare(Fact(Macro=en4.get()))
			self.declare(Fact(Programming=en5.get()))
			self.declare(Fact(SQL=en6.get()))
			self.declare(Fact(No_SQL=en7.get()))
			self.declare(Fact(Architecture=en8.get()))
			self.declare(Fact(Civil=en9.get()))
			self.declare(Fact(Family=en10.get()))
			self.declare(Fact(Criminal=en11.get()))
#############################################################################
		btn = Button(gui_form1,command=get_values,text="SHOW BOOK",bg="#5B4C42", fg="#FFFFFF" , width=13 )
		btn.config(font=("Arial", 10))
		btn.pack(pady=5)
                 
		gui_form1.mainloop()
		yield Fact(action="find_books")
        

###################################################################################################
##################################################################################################

	@Rule(Fact(action='find_books'),Fact(pediatrics="yes"),Fact(Medicine="no") ,Fact(Micro="no"),Fact(Macro="no"),Fact(Programming="no"),Fact(SQL="no"),Fact(No_SQL="no"),Fact(Architecture="no"),Fact(Civil="no"),Fact(Family="no"),Fact(Criminal="no"))
	def value_0(self):
		self.declare(Fact(novel="Illustrated Textbook of Pediatrics"))
        
	@Rule(Fact(action='find_books'),Fact(pediatrics="no"),Fact(Medicine="yes") ,Fact(Micro="no"),Fact(Macro="no"),Fact(Programming="no"),Fact(SQL="no"),Fact(No_SQL="no"),Fact(Architecture="no"),Fact(Civil="no"),Fact(Family="no"),Fact(Criminal="no"))
	def value_1(self):
		self.declare(Fact(novel="Pocket Medicine"))
        
	@Rule(Fact(action='find_books'),Fact(pediatrics="no"),Fact(Medicine="no") ,Fact(Micro="yes"),Fact(Macro="no"),Fact(Programming="no"),Fact(SQL="no"),Fact(No_SQL="no"),Fact(Architecture="no"),Fact(Civil="no"),Fact(Family="no"),Fact(Criminal="no"))        
	def value_2(self):
		self.declare(Fact(novel="Principles of Microeconomics 2e "))
        
        
	@Rule(Fact(action='find_books'),Fact(pediatrics="no"),Fact(Medicine="no") ,Fact(Micro="no"),Fact(Macro="yes"),Fact(Programming="no"),Fact(SQL="no"),Fact(No_SQL="no"),Fact(Architecture="no"),Fact(Civil="no"),Fact(Family="no"),Fact(Criminal="no"))        
	def value_3(self):
		self.declare(Fact(novel="Principles of Macroeconomics 3e"))
        
	@Rule(Fact(action='find_books'),Fact(pediatrics="no"),Fact(Medicine="no") ,Fact(Micro="no"),Fact(Macro="no"),Fact(Programming="yes"),Fact(SQL="no"),Fact(No_SQL="no"),Fact(Architecture="no"),Fact(Civil="no"),Fact(Family="no"),Fact(Criminal="no"))        
	def value_4(self):
		self.declare(Fact(novel="Python Crash Course"))
        
        
	@Rule(Fact(action='find_books'),Fact(pediatrics="no"),Fact(Medicine="no") ,Fact(Micro="no"),Fact(Macro="no"),Fact(Programming="no"),Fact(SQL="yes"),Fact(No_SQL="no"),Fact(Architecture="no"),Fact(Civil="no"),Fact(Family="no"),Fact(Criminal="no"))        
	def value_5(self):
		self.declare(Fact(novel="SQL Cookbook"))
        
        
	@Rule(Fact(action='find_books'),Fact(pediatrics="no"),Fact(Medicine="no") ,Fact(Micro="no"),Fact(Macro="no"),Fact(Programming="no"),Fact(SQL="no"),Fact(No_SQL="yes"),Fact(Architecture="no"),Fact(Civil="no"),Fact(Family="no"),Fact(Criminal="no"))        
	def value_6(self):
		self.declare(Fact(novel="No-SQL for Dummies"))
        

	@Rule(Fact(action='find_books'),Fact(pediatrics="no"),Fact(Medicine="no") ,Fact(Micro="no"),Fact(Macro="no"),Fact(Programming="no"),Fact(SQL="no"),Fact(No_SQL="no"),Fact(Architecture="yes"),Fact(Civil="no"),Fact(Family="no"),Fact(Criminal="no"))
	def value_7(self):
		self.declare(Fact(novel="The Architecture of the city "))
        
        
	@Rule(Fact(action='find_books'),Fact(pediatrics="no"),Fact(Medicine="no") ,Fact(Micro="no"),Fact(Macro="no"),Fact(Programming="no"),Fact(SQL="no"),Fact(No_SQL="no"),Fact(Architecture="no"),Fact(Civil="yes"),Fact(Family="no"),Fact(Criminal="no"))        
	def value_8(self):
		self.declare(Fact(novel="Pipe fitters Blue Book"))
        
	@Rule(Fact(action='find_books'),Fact(pediatrics="no"),Fact(Medicine="no") ,Fact(Micro="no"),Fact(Macro="no"),Fact(Programming="no"),Fact(SQL="no"),Fact(No_SQL="no"),Fact(Architecture="no"),Fact(Civil="no"),Fact(Family="yes"),Fact(Criminal="no"))        
	def value_9(self):
		self.declare(Fact(novel="Family Law and Practice"))
        
        
	@Rule(Fact(action='find_books'),Fact(pediatrics="no"),Fact(Medicine="no") ,Fact(Micro="no"),Fact(Macro="no"),Fact(Programming="no"),Fact(SQL="no"),Fact(No_SQL="no"),Fact(Architecture="no"),Fact(Civil="no"),Fact(Family="no"),Fact(Criminal="yes"))        
	def value_10(self):
		self.declare(Fact(novel="Criminal Will Trent "))
        

	@Rule(Fact(action='find_books'),Fact(pediatrics="no"),Fact(Medicine="no") ,Fact(Micro="no"),Fact(Macro="no"),Fact(Programming="no"),Fact(SQL="no"),Fact(No_SQL="no"),Fact(Architecture="no"),Fact(Civil="no"),Fact(Family="no"),Fact(Criminal="no"))        
	def value_11(self):
		self.declare(Fact(novel="Error!"))
        


###################################################################################################
##################################################################################################
	@Rule(Fact(action='find_books'),Fact(novel=MATCH.novel))
	def my_novel(self, novel):
		print("")
		my_novel = novel
		gui_form2 = Tk()
		gui_form2.configure(bg="#FFFFFF")
		gui_form2.title("Library expert system answer")
		gui_form2.geometry("800x500")
		lb0 = Label(gui_form2,text="We Recommend This Book to You :", bg="#FFFFFF", fg="#000000")
		lb0.pack(pady=25)
		lb0.config(font=("Helvetica", 20 , "bold"  ) , width=100 )
		var = StringVar()
		var.set(my_novel)
		lb1 = Label(gui_form2, textvariable = var,bg="#FFFFFF", fg="#000000")
		lb1.config(font=("Helvetica", 20 , "bold"  , "italic") , width=120 )
		lb1.pack(pady=10)
		frame = Frame(gui_form2, width=200, height=200)
		frame.pack(pady=60)
		img = ImageTk.PhotoImage(Image.open("cover34.png"))
		label = Label(frame, image = img)
		label.pack()
		gui_form2.mainloop()

###################################################################################################
##################################################################################################
        
engine = find_books()
while(1):
    engine.reset()
    engine.run()  
    print("Would you like to get another recommendation of Books?")
    if input() == "no":
        break;
# Out:
# Would you like to get another recommendation of Books?
