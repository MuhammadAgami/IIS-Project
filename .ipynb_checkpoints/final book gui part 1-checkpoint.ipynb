# %%
from tkinter import *
from PIL import ImageTk, Image
import customtkinter
from experta import *
class find_books(KnowledgeEngine):
	@DefFacts()
	def _initial_action(self):
		gui_form1 = Tk()
		#gui_form.configure(bg="#FFFFFF")
		gui_form1.title("Library Expert System")
###############################################################################
		photo=PhotoImage(file = "book-clip-art-4.png")
		res=photo.subsample(10,10)
		btn=Label(gui_form1 , image=res , width=500 )
		btn.pack()
        
###############################################################################

###############################################################################
		mylb1 = Label(gui_form1,text="‣ Language Section" ,fg="#000000" , font=("Helvetica", 12 , "bold" ))
		mylb1.pack()
		lb1 = Label(gui_form1,text=" English " ,fg="#643719" )
		en1 = Entry(gui_form1  , width=40)
		lb1.pack()
		en1.pack()
###############################################################################
		lb2 = Label(gui_form1,text="German",fg="#643719" )
		en2 = Entry(gui_form1 , width=40)
		lb2.pack()
		en2.pack()
###############################################################################
		mylb3 = Label(gui_form1,text="‣ Astronomy Section" ,fg="#000000" , font=("Helvetica", 12 , "bold" ))
		mylb3.pack()
		lb3 = Label(gui_form1,text="Astro-Statistics",fg="#643719")
		en3 = Entry(gui_form1, width=40)
		lb3.pack()
		en3.pack()
###############################################################################
		lb4 = Label(gui_form1,text="Cosmology",fg="#643719")
		en4 = Entry(gui_form1, width=40)
		lb4.pack()
		en4.pack()
###############################################################################
		mylb5 = Label(gui_form1,text="‣ Plant-Science Section" ,fg="#000000" , font=("Helvetica", 12 , "bold"))
		mylb5.pack()
		lb5 = Label(gui_form1,text="Cytology ",fg="#643719")
		en5 = Entry(gui_form1, width=40)
		lb5.pack()
		en5.pack()
###############################################################################
		lb6 = Label(gui_form1,text="Epigenetics" ,fg="#643719")
		en6 = Entry(gui_form1, width=40)
		lb6.pack()
		en6.pack()
###############################################################################
		mylb7 = Label(gui_form1,text="‣ Animal Science Section" ,fg="#000000" , font=("Helvetica", 12 , "bold") )
		mylb7.pack()
		lb7= Label(gui_form1,text="Physiology" ,fg="#643719")
		en7= Entry(gui_form1, width=40)
		lb7.pack()
		en7.pack()
###############################################################################
		lb8 = Label(gui_form1,text="Epigenetics" ,fg="#643719")
		en8 = Entry(gui_form1, width=40)
		lb8.pack()
		en8.pack()
###############################################################################
		mylb9 = Label(gui_form1,text="‣ Indusrties Section" ,fg="#000000" , font=("Helvetica", 12 , "bold") )
		mylb9.pack()
		lb9 = Label(gui_form1,text="Chemical" ,fg="#643719")
		en9 = Entry(gui_form1, width=40)
		lb9.pack()
		en9.pack()
###############################################################################
		lb10 = Label(gui_form1,text="Basic-Metal Production" ,fg="#643719")
		en10 = Entry(gui_form1, width=40)
		lb10.pack()
		en10.pack()
###############################################################################
		mylb11 = Label(gui_form1,text="‣ Fine-arts Section" ,fg="#000000" , font=("Helvetica", 12 , "bold") )
		mylb11.pack()
		lb11 = Label(gui_form1,text="Drawing" ,fg="#643719")
		en11 = Entry(gui_form1, width=40)
		lb11.pack()
		en11.pack()
###############################################################################
		lb12 = Label(gui_form1,text="Music" ,fg="#643719")
		en12= Entry(gui_form1, width=40)
		lb12.pack()
		en12.pack()
##############################################################################
		def get_values():
			#lb2["text"] = en2.get()
			self.declare(Fact(English_language=en1.get()))
			self.declare(Fact(German_language=en2.get()))
			self.declare(Fact(Astronomy_statistics=en3.get()))
			self.declare(Fact(Astronomy_cosmology=en4.get()))
			self.declare(Fact(Cytology=en5.get()))
			self.declare(Fact(Epigenetics=en6.get()))
			self.declare(Fact(Physiology=en7.get()))
			self.declare(Fact(Animal_Epigenetics=en8.get()))
			self.declare(Fact(Industries_chemical=en9.get()))
			self.declare(Fact(Industries_production=en10.get()))
			self.declare(Fact(Draw=en11.get()))
			self.declare(Fact(Music=en12.get()))
#############################################################################
		btn = Button(gui_form1,command=get_values,text="SHOW BOOK",bg="#5B4C42", fg="#FFFFFF" , pady=5 , width=13 )
		btn.config(font=("Arial", 10))
		btn.pack(pady=5)
                 
		gui_form1.mainloop()
		yield Fact(action="find_books")
        

###################################################################################################
##################################################################################################

	@Rule(Fact(action='find_books'),Fact(English_language="yes"),Fact(German_language="no") ,Fact(Astronomy_cosmology="no"),Fact(Astronomy_statistics="no"),Fact(Cytology="no"),Fact(Epigenetics="no"),Fact(Physiology="no"),Fact(Animal_Epigenetics="no"),Fact(Industries_chemical="no"),Fact(Industries_production="no"),Fact(Draw="no"),Fact(Music="no"))
	def value_0(self):
		self.declare(Fact(novel="English for Everyone"))
        
	@Rule(Fact(action='find_books'),Fact(English_language="no"),Fact(German_language="yes") ,Fact(Astronomy_cosmology="no"),Fact(Astronomy_statistics="no"),Fact(Cytology="no"),Fact(Epigenetics="no"),Fact(Physiology="no"),Fact(Animal_Epigenetics="no"),Fact(Industries_chemical="no"),Fact(Industries_production="no"),Fact(Draw="no"),Fact(Music="no"))
	def value_1(self):
		self.declare(Fact(novel="German all-in-one"))
        
	@Rule(Fact(action='find_books'),Fact(English_language="no"),Fact(German_language="no") ,Fact(Astronomy_cosmology="yes"),Fact(Astronomy_statistics="no"),Fact(Cytology="no"),Fact(Epigenetics="no"),Fact(Physiology="no"),Fact(Animal_Epigenetics="no"),Fact(Industries_chemical="no"),Fact(Industries_production="no"),Fact(Draw="no"),Fact(Music="no"))
	def value_2(self):
		self.declare(Fact(novel="The First Three Minutes"))
        
	@Rule(Fact(action='find_books'),Fact(English_language="no"),Fact(German_language="no") ,Fact(Astronomy_cosmology="no"),Fact(Astronomy_statistics="yes"),Fact(Cytology="no"),Fact(Epigenetics="no"),Fact(Physiology="no"),Fact(Animal_Epigenetics="no"),Fact(Industries_chemical="no"),Fact(Industries_production="no"),Fact(Draw="no"),Fact(Music="no"))
	def value_3(self):
		self.declare(Fact(novel="Astro-Statistics With Data Mining"))
        
	@Rule(Fact(action='find_books'),Fact(English_language="no"),Fact(German_language="no") ,Fact(Astronomy_cosmology="no"),Fact(Astronomy_statistics="no"),Fact(Cytology="yes"),Fact(Epigenetics="no"),Fact(Physiology="no"),Fact(Animal_Epigenetics="no"),Fact(Industries_chemical="no"),Fact(Industries_production="no"),Fact(Draw="no"),Fact(Music="no"))
	def value_4(self):
		self.declare(Fact(novel="Cytology Diagnostic Principles 5th Edition"))
        
	@Rule(Fact(action='find_books'),Fact(English_language="no"),Fact(German_language="no") ,Fact(Astronomy_cosmology="no"),Fact(Astronomy_statistics="no"),Fact(Cytology="no"),Fact(Epigenetics="yes"),Fact(Physiology="no"),Fact(Animal_Epigenetics="no"),Fact(Industries_chemical="no"),Fact(Industries_production="no"),Fact(Draw="no"),Fact(Music="no"))
	def value_5(self):
		self.declare(Fact(novel="The Epigenetics Revolution"))
        
	@Rule(Fact(action='find_books'),Fact(English_language="no"),Fact(German_language="no") ,Fact(Astronomy_cosmology="no"),Fact(Astronomy_statistics="no"),Fact(Cytology="no"),Fact(Epigenetics="no"),Fact(Physiology="yes"),Fact(Animal_Epigenetics="no"),Fact(Industries_chemical="no"),Fact(Industries_production="no"),Fact(Draw="no"),Fact(Music="no"))
	def value_6(self):
		self.declare(Fact(novel="Gray's Anatomy International Edition"))

	@Rule(Fact(action='find_books'),Fact(English_language="no"),Fact(German_language="no") ,Fact(Astronomy_cosmology="no"),Fact(Astronomy_statistics="no"),Fact(Cytology="no"),Fact(Epigenetics="no"),Fact(Physiology="no"),Fact(Animal_Epigenetics="yes"),Fact(Industries_chemical="no"),Fact(Industries_production="no"),Fact(Draw="no"),Fact(Music="no"))
	def value_7(self):
		self.declare(Fact(novel="Epigenetics And Chromatin"))
        
	@Rule(Fact(action='find_books'),Fact(English_language="no"),Fact(German_language="no") ,Fact(Astronomy_cosmology="no"),Fact(Astronomy_statistics="no"),Fact(Cytology="no"),Fact(Epigenetics="no"),Fact(Physiology="no"),Fact(Animal_Epigenetics="no"),Fact(Industries_chemical="yes"),Fact(Industries_production="no"),Fact(Draw="no"),Fact(Music="no"))
	def value_8(self):
		self.declare(Fact(novel="Handbook of Chemical Industries"))
        
	@Rule(Fact(action='find_books'),Fact(English_language="no"),Fact(German_language="no") ,Fact(Astronomy_cosmology="no"),Fact(Astronomy_statistics="no"),Fact(Cytology="no"),Fact(Epigenetics="no"),Fact(Physiology="no"),Fact(Animal_Epigenetics="no"),Fact(Industries_chemical="no"),Fact(Industries_production="yes"),Fact(Draw="no"),Fact(Music="no"))
	def value_9(self):
		self.declare(Fact(novel="Principles of Extractive Metallurgy"))
        
	@Rule(Fact(action='find_books'),Fact(English_language="no"),Fact(German_language="no") ,Fact(Astronomy_cosmology="no"),Fact(Astronomy_statistics="no"),Fact(Cytology="no"),Fact(Epigenetics="no"),Fact(Physiology="no"),Fact(Animal_Epigenetics="no"),Fact(Industries_chemical="no"),Fact(Industries_production="no"),Fact(Draw="yes"),Fact(Music="no"))
	def value_10(self):
		self.declare(Fact(novel="The Art Book or The Artist's Eye "))
        
	@Rule(Fact(action='find_books'),Fact(English_language="no"),Fact(German_language="no") ,Fact(Astronomy_cosmology="no"),Fact(Astronomy_statistics="no"),Fact(Cytology="no"),Fact(Epigenetics="no"),Fact(Physiology="no"),Fact(Animal_Epigenetics="no"),Fact(Industries_chemical="no"),Fact(Industries_production="no"),Fact(Draw="no"),Fact(Music="yes"))
	def value_11(self):
		self.declare(Fact(novel="How Music Works"))
        
	@Rule(Fact(action='find_books'),Fact(English_language="no"),Fact(German_language="no") ,Fact(Astronomy_cosmology="no"),Fact(Astronomy_statistics="no"),Fact(Cytology="no"),Fact(Epigenetics="no"),Fact(Physiology="no"),Fact(Animal_Epigenetics="no"),Fact(Industries_chemical="no"),Fact(Industries_production="no"),Fact(Draw="no"),Fact(Music="no"))
	def value_12(self):
		self.declare(Fact(novel="ERORR"))

###################################################################################################
##################################################################################################
	@Rule(Fact(action='find_books'),Fact(novel=MATCH.novel))
	def my_novel(self, novel):
		print("")
		my_novel = novel
		gui_form2 = Tk()
		gui_form2.configure(bg="#FFFFFF")
		gui_form2.title("Library expert system answer")
		gui_form2.geometry("800x500")
		lb0 = Label(gui_form2,text="We Recommend This Book to You :", bg="#FFFFFF", fg="#000000")
		lb0.pack(pady=25)
		lb0.config(font=("Helvetica", 20 , "bold"  ) , width=100 )
		var = StringVar()
		var.set(my_novel)
		lb1 = Label(gui_form2, textvariable = var,bg="#FFFFFF", fg="#000000")
		lb1.config(font=("Helvetica", 20 , "bold"  , "italic") , width=120 )
		lb1.pack(pady=10)
		frame = Frame(gui_form2, width=200, height=200)
		frame.pack(pady=60)
		img = ImageTk.PhotoImage(Image.open("cover34.png"))
		label = Label(frame, image = img)
		label.pack()
		gui_form2.mainloop()

###################################################################################################
##################################################################################################
        
engine = find_books()
while(1):
    engine.reset()
    engine.run()  
    print("Would you like to get another recommendation of Books?")
    if input() == "no":
        break;
# Out:
# WARNING:experta.watchers.ENGINE:Declaring fact before reset()
# Would you like to get another recommendation of Books?
